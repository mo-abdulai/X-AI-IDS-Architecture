# %% [markdown]
# # XGBoost MODEL BUILD

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import psutil  # For measuring system resources
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import train_test_split
import joblib
from xgboost import XGBClassifier
from xgboost import plot_importance

# Function to measure CPU, Memory, and Disk I/O usage
def measure_system_resources():
    cpu_usage = psutil.cpu_percent(interval=1)
    memory_info = psutil.virtual_memory()
    disk_io = psutil.disk_io_counters()

    memory_used = memory_info.used / (1024 * 1024)  # Convert to MB
    disk_io_used = (disk_io.read_bytes + disk_io.write_bytes) / (1024 * 1024)  # Convert to MB

    return cpu_usage, memory_used, disk_io_used

# %% [markdown]
# ## Load Train and Test Datasets

# %%
# Load datasets
train_data = pd.read_csv('../../2_Modeling-Phase/train_and_test_datasets/CICIDS-2017/train.csv')
test_data = pd.read_csv('../../2_Modeling-Phase/train_and_test_datasets/CICIDS-2017/test.csv')

# Splitting features and labels
X_train = train_data.drop(['label'], axis=1)  # Features
y_train = train_data['label']  # Target variable
X_test = test_data.drop(['label'], axis=1)  # Features
y_test = test_data['label']  # Target variable

# %% [markdown]
# # Splitting Training Set for Validation

# %%
# Splitting the training data for validation
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# # Visualizing PCA Data

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(
    X_train.iloc[:, 0], X_train.iloc[:, 1], X_train.iloc[:, 2], 
    c=y_train, cmap='coolwarm', alpha=0.7
)

ax.set_xlabel("Principal Component 1")
ax.set_ylabel("Principal Component 2")
ax.set_zlabel("Principal Component 3")
ax.set_title("3D PCA Projection (Training Data)")

plt.colorbar(scatter, ax=ax, label='Label')
plt.show()



# Calculate explained variance ratio manually
explained_variance = np.var(X_train, axis=0) / np.sum(np.var(X_train, axis=0))

# Plot cumulative explained variance
plt.figure(figsize=(8, 5))
plt.plot(np.cumsum(explained_variance), marker='o', linestyle='--')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance by Principal Components')
plt.grid()
plt.show()

# %% [markdown]
# # Model Creation and Training (XGBoost)

# %%
# 'n_estimators' sets the number of boosting rounds.
# 'max_depth' controls the maximum depth of each tree.
# 'learning_rate' determines the step size at each iteration.
# 'objective' defines the loss function to be optimized.
model = XGBClassifier(
    n_estimators=1500,  
    max_depth=5,        
    learning_rate=0.05,  
    objective='binary:logistic'
)

model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1500, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
# Validation
pred = model.predict(X_test)

# %%
# Start time and system resource tracking
start_time = time.time()
cpu_before, memory_before, disk_io_before = measure_system_resources()

# Initialize and train the XGBoost model
xgb_model = xgb.XGBClassifier(
    n_estimators=500,
    max_depth=10,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1
)

# Train the model
xgb_model.fit(X_train, y_train, eval_set=[(X_val, y_val)], verbose=True)

# End time and resource tracking
end_time = time.time()
cpu_after, memory_after, disk_io_after = measure_system_resources()
execution_time = end_time - start_time

cpu_usage_change = cpu_after - cpu_before
memory_used = memory_after - memory_before
disk_io_used = disk_io_after - disk_io_before

# Report computational overhead
print("\n🚀 **Computational Overhead Report (XGBoost Training)** 🚀")
print(f"⏳ **Execution Time:** {execution_time:.4f} seconds")
print(f"🔥 **CPU Usage Change:** {cpu_usage_change:.2f}%")
print(f"💾 **Disk I/O Usage:** {disk_io_used:.2f} MB")
print(f"📊 **Memory Usage:** {memory_used:.2f} MB")
# Out:
# [0]	validation_0-logloss:0.59174
# [1]	validation_0-logloss:0.51443
# [2]	validation_0-logloss:0.45014
# [3]	validation_0-logloss:0.39587
# [4]	validation_0-logloss:0.34956
# [5]	validation_0-logloss:0.30969
# [6]	validation_0-logloss:0.27513
# [7]	validation_0-logloss:0.24499
# [8]	validation_0-logloss:0.21860
# [9]	validation_0-logloss:0.19537
# [10]	validation_0-logloss:0.17488
# [11]	validation_0-logloss:0.15673
# [12]	validation_0-logloss:0.14059
# [13]	validation_0-logloss:0.12627
# [14]	validation_0-logloss:0.11347
# [15]	validation_0-logloss:0.10209
# [16]	validation_0-logloss:0.09187
# [17]	validation_0-logloss:0.08274
# [18]	validation_0-logloss:0.07454
# [19]	validation_0-logloss:0.06720
# [20]	validation_0-logloss:0.06060
# [21]	validation_0-logloss:0.05468
# [22]	validation_0-logloss:0.04936
# [23]	validation_0-logloss:0.04457
# [24]	validation_0-logloss:0.04025
# [25]	validation_0-logloss:0.03636
# [26]	validation_0-logloss:0.03286
# [27]	validation_0-logloss:0.02970
# [28]	validation_0-logloss:0.02686
# [29]	validation_0-logloss:0.02429
# [30]	validation_0-logloss:0.02198
# [31]	validation_0-logloss:0.01988
# [32]	validation_0-logloss:0.01800
# [33]	validation_0-logloss:0.01629
# [34]	validation_0-logloss:0.01475
# [35]	validation_0-logloss:0.01336
# [36]	validation_0-logloss:0.01210
# [37]	validation_0-logloss:0.01096
# [38]	validation_0-logloss:0.00993
# [39]	validation_0-logloss:0.00900
# [40]	validation_0-logloss:0.00816
# [41]	validation_0-logloss:0.00741
# [42]	validation_0-logloss:0.00672
# [43]	validation_0-logloss:0.00610
# [44]	validation_0-logloss:0.00554
# [45]	validation_0-logloss:0.00503
# [46]	validation_0-logloss:0.00457
# [47]	validation_0-logloss:0.00415
# [48]	validation_0-logloss:0.00377
# [49]	validation_0-logloss:0.00344
# [50]	validation_0-logloss:0.00313
# [51]	validation_0-logloss:0.00285
# [52]	validation_0-logloss:0.00260
# [53]	validation_0-logloss:0.00237
# [54]	validation_0-logloss:0.00216
# [55]	validation_0-logloss:0.00197
# [56]	validation_0-logloss:0.00180
# [57]	validation_0-logloss:0.00165
# [58]	validation_0-logloss:0.00151
# [59]	validation_0-logloss:0.00139
# [60]	validation_0-logloss:0.00127
# [61]	validation_0-logloss:0.00117
# [62]	validation_0-logloss:0.00107
# [63]	validation_0-logloss:0.00099
# [64]	validation_0-logloss:0.00091
# [65]	validation_0-logloss:0.00084
# [66]	validation_0-logloss:0.00078
# [67]	validation_0-logloss:0.00072
# [68]	validation_0-logloss:0.00066
# [69]	validation_0-logloss:0.00062
# [70]	validation_0-logloss:0.00057
# [71]	validation_0-logloss:0.00053
# [72]	validation_0-logloss:0.00050
# [73]	validation_0-logloss:0.00046
# [74]	validation_0-logloss:0.00043
# [75]	validation_0-logloss:0.00041
# [76]	validation_0-logloss:0.00038
# [77]	validation_0-logloss:0.00036
# [78]	validation_0-logloss:0.00034
# [79]	validation_0-logloss:0.00032
# [80]	validation_0-logloss:0.00030
# [81]	validation_0-logloss:0.00028
# [82]	validation_0-logloss:0.00027
# [83]	validation_0-logloss:0.00025
# [84]	validation_0-logloss:0.00023
# [85]	validation_0-logloss:0.00022
# [86]	validation_0-logloss:0.00021
# [87]	validation_0-logloss:0.00020
# [88]	validation_0-logloss:0.00019
# [89]	validation_0-logloss:0.00018
# [90]	validation_0-logloss:0.00018
# [91]	validation_0-logloss:0.00017
# [92]	validation_0-logloss:0.00016
# [93]	validation_0-logloss:0.00015
# [94]	validation_0-logloss:0.00015
# [95]	validation_0-logloss:0.00014
# [96]	validation_0-logloss:0.00013
# [97]	validation_0-logloss:0.00013
# [98]	validation_0-logloss:0.00012
# [99]	validation_0-logloss:0.00012
# [100]	validation_0-logloss:0.00011
# [101]	validation_0-logloss:0.00011
# [102]	validation_0-logloss:0.00010
# [103]	validation_0-logloss:0.00010
# [104]	validation_0-logloss:0.00010
# [105]	validation_0-logloss:0.00009
# [106]	validation_0-logloss:0.00009
# [107]	validation_0-logloss:0.00008
# [108]	validation_0-logloss:0.00008
# [109]	validation_0-logloss:0.00008
# [110]	validation_0-logloss:0.00008
# [111]	validation_0-logloss:0.00007
# [112]	validation_0-logloss:0.00007
# [113]	validation_0-logloss:0.00007
# [114]	validation_0-logloss:0.00007
# [115]	validation_0-logloss:0.00007
# [116]	validation_0-logloss:0.00006
# [117]	validation_0-logloss:0.00006
# [118]	validation_0-logloss:0.00006
# [119]	validation_0-logloss:0.00006
# [120]	validation_0-logloss:0.00006
# [121]	validation_0-logloss:0.00006
# [122]	validation_0-logloss:0.00006
# [123]	validation_0-logloss:0.00006
# [124]	validation_0-logloss:0.00005
# [125]	validation_0-logloss:0.00005
# [126]	validation_0-logloss:0.00005
# [127]	validation_0-logloss:0.00005
# [128]	validation_0-logloss:0.00005
# [129]	validation_0-logloss:0.00005
# [130]	validation_0-logloss:0.00005
# [131]	validation_0-logloss:0.00005
# [132]	validation_0-logloss:0.00005
# [133]	validation_0-logloss:0.00005
# [134]	validation_0-logloss:0.00005
# [135]	validation_0-logloss:0.00004
# [136]	validation_0-logloss:0.00004
# [137]	validation_0-logloss:0.00004
# [138]	validation_0-logloss:0.00004
# [139]	validation_0-logloss:0.00004
# [140]	validation_0-logloss:0.00004
# [141]	validation_0-logloss:0.00004
# [142]	validation_0-logloss:0.00004
# [143]	validation_0-logloss:0.00004
# [144]	validation_0-logloss:0.00004
# [145]	validation_0-logloss:0.00004
# [146]	validation_0-logloss:0.00004
# [147]	validation_0-logloss:0.00004
# [148]	validation_0-logloss:0.00004
# [149]	validation_0-logloss:0.00004
# [150]	validation_0-logloss:0.00004
# [151]	validation_0-logloss:0.00004
# [152]	validation_0-logloss:0.00004
# [153]	validation_0-logloss:0.00004
# [154]	validation_0-logloss:0.00003
# [155]	validation_0-logloss:0.00003
# [156]	validation_0-logloss:0.00003
# [157]	validation_0-logloss:0.00003
# [158]	validation_0-logloss:0.00003
# [159]	validation_0-logloss:0.00003
# [160]	validation_0-logloss:0.00003
# [161]	validation_0-logloss:0.00003
# [162]	validation_0-logloss:0.00003
# [163]	validation_0-logloss:0.00003
# [164]	validation_0-logloss:0.00003
# [165]	validation_0-logloss:0.00003
# [166]	validation_0-logloss:0.00003
# [167]	validation_0-logloss:0.00003
# [168]	validation_0-logloss:0.00003
# [169]	validation_0-logloss:0.00003
# [170]	validation_0-logloss:0.00003
# [171]	validation_0-logloss:0.00003
# [172]	validation_0-logloss:0.00003
# [173]	validation_0-logloss:0.00003
# [174]	validation_0-logloss:0.00003
# [175]	validation_0-logloss:0.00003
# [176]	validation_0-logloss:0.00003
# [177]	validation_0-logloss:0.00003
# [178]	validation_0-logloss:0.00003
# [179]	validation_0-logloss:0.00003
# [180]	validation_0-logloss:0.00003
# [181]	validation_0-logloss:0.00003
# [182]	validation_0-logloss:0.00003
# [183]	validation_0-logloss:0.00003
# [184]	validation_0-logloss:0.00003
# [185]	validation_0-logloss:0.00003
# [186]	validation_0-logloss:0.00003
# [187]	validation_0-logloss:0.00003
# [188]	validation_0-logloss:0.00003
# [189]	validation_0-logloss:0.00003
# [190]	validation_0-logloss:0.00003
# [191]	validation_0-logloss:0.00003
# [192]	validation_0-logloss:0.00003
# [193]	validation_0-logloss:0.00003
# [194]	validation_0-logloss:0.00003
# [195]	validation_0-logloss:0.00003
# [196]	validation_0-logloss:0.00003
# [197]	validation_0-logloss:0.00003
# [198]	validation_0-logloss:0.00003
# [199]	validation_0-logloss:0.00003
# [200]	validation_0-logloss:0.00003
# [201]	validation_0-logloss:0.00003
# [202]	validation_0-logloss:0.00003
# [203]	validation_0-logloss:0.00003
# [204]	validation_0-logloss:0.00003
# [205]	validation_0-logloss:0.00003
# [206]	validation_0-logloss:0.00003
# [207]	validation_0-logloss:0.00003
# [208]	validation_0-logloss:0.00003
# [209]	validation_0-logloss:0.00003
# [210]	validation_0-logloss:0.00003
# [211]	validation_0-logloss:0.00003
# [212]	validation_0-logloss:0.00003
# [213]	validation_0-logloss:0.00003
# [214]	validation_0-logloss:0.00003
# [215]	validation_0-logloss:0.00003
# [216]	validation_0-logloss:0.00003
# [217]	validation_0-logloss:0.00003
# [218]	validation_0-logloss:0.00003
# [219]	validation_0-logloss:0.00003
# [220]	validation_0-logloss:0.00003
# [221]	validation_0-logloss:0.00003
# [222]	validation_0-logloss:0.00003
# [223]	validation_0-logloss:0.00002
# [224]	validation_0-logloss:0.00002
# [225]	validation_0-logloss:0.00002
# [226]	validation_0-logloss:0.00002
# [227]	validation_0-logloss:0.00002
# [228]	validation_0-logloss:0.00002
# [229]	validation_0-logloss:0.00002
# [230]	validation_0-logloss:0.00002
# [231]	validation_0-logloss:0.00002
# [232]	validation_0-logloss:0.00002
# [233]	validation_0-logloss:0.00002
# [234]	validation_0-logloss:0.00002
# [235]	validation_0-logloss:0.00002
# [236]	validation_0-logloss:0.00002
# [237]	validation_0-logloss:0.00002
# [238]	validation_0-logloss:0.00002
# [239]	validation_0-logloss:0.00002
# [240]	validation_0-logloss:0.00002
# [241]	validation_0-logloss:0.00002
# [242]	validation_0-logloss:0.00002
# [243]	validation_0-logloss:0.00002
# [244]	validation_0-logloss:0.00002
# [245]	validation_0-logloss:0.00002
# [246]	validation_0-logloss:0.00002
# [247]	validation_0-logloss:0.00002
# [248]	validation_0-logloss:0.00002
# [249]	validation_0-logloss:0.00002
# [250]	validation_0-logloss:0.00002
# [251]	validation_0-logloss:0.00002
# [252]	validation_0-logloss:0.00002
# [253]	validation_0-logloss:0.00002
# [254]	validation_0-logloss:0.00002
# [255]	validation_0-logloss:0.00002
# [256]	validation_0-logloss:0.00002
# [257]	validation_0-logloss:0.00002
# [258]	validation_0-logloss:0.00002
# [259]	validation_0-logloss:0.00002
# [260]	validation_0-logloss:0.00002
# [261]	validation_0-logloss:0.00002
# [262]	validation_0-logloss:0.00002
# [263]	validation_0-logloss:0.00002
# [264]	validation_0-logloss:0.00002
# [265]	validation_0-logloss:0.00002
# [266]	validation_0-logloss:0.00002
# [267]	validation_0-logloss:0.00002
# [268]	validation_0-logloss:0.00002
# [269]	validation_0-logloss:0.00002
# [270]	validation_0-logloss:0.00002
# [271]	validation_0-logloss:0.00002
# [272]	validation_0-logloss:0.00002
# [273]	validation_0-logloss:0.00002
# [274]	validation_0-logloss:0.00002
# [275]	validation_0-logloss:0.00002
# [276]	validation_0-logloss:0.00002
# [277]	validation_0-logloss:0.00002
# [278]	validation_0-logloss:0.00002
# [279]	validation_0-logloss:0.00002
# [280]	validation_0-logloss:0.00002
# [281]	validation_0-logloss:0.00002
# [282]	validation_0-logloss:0.00002
# [283]	validation_0-logloss:0.00002
# [284]	validation_0-logloss:0.00002
# [285]	validation_0-logloss:0.00002
# [286]	validation_0-logloss:0.00002
# [287]	validation_0-logloss:0.00002
# [288]	validation_0-logloss:0.00002
# [289]	validation_0-logloss:0.00002
# [290]	validation_0-logloss:0.00002
# [291]	validation_0-logloss:0.00002
# [292]	validation_0-logloss:0.00002
# [293]	validation_0-logloss:0.00002
# [294]	validation_0-logloss:0.00002
# [295]	validation_0-logloss:0.00002
# [296]	validation_0-logloss:0.00002
# [297]	validation_0-logloss:0.00002
# [298]	validation_0-logloss:0.00002
# [299]	validation_0-logloss:0.00002
# [300]	validation_0-logloss:0.00002
# [301]	validation_0-logloss:0.00002
# [302]	validation_0-logloss:0.00002
# [303]	validation_0-logloss:0.00002
# [304]	validation_0-logloss:0.00002
# [305]	validation_0-logloss:0.00002
# [306]	validation_0-logloss:0.00002
# [307]	validation_0-logloss:0.00002
# [308]	validation_0-logloss:0.00002
# [309]	validation_0-logloss:0.00002
# [310]	validation_0-logloss:0.00002
# [311]	validation_0-logloss:0.00002
# [312]	validation_0-logloss:0.00002
# [313]	validation_0-logloss:0.00002
# [314]	validation_0-logloss:0.00002
# [315]	validation_0-logloss:0.00002
# [316]	validation_0-logloss:0.00002
# [317]	validation_0-logloss:0.00002
# [318]	validation_0-logloss:0.00002
# [319]	validation_0-logloss:0.00002
# [320]	validation_0-logloss:0.00002
# [321]	validation_0-logloss:0.00002
# [322]	validation_0-logloss:0.00002
# [323]	validation_0-logloss:0.00002
# [324]	validation_0-logloss:0.00002
# [325]	validation_0-logloss:0.00002
# [326]	validation_0-logloss:0.00002
# [327]	validation_0-logloss:0.00002
# [328]	validation_0-logloss:0.00002
# [329]	validation_0-logloss:0.00002
# [330]	validation_0-logloss:0.00002
# [331]	validation_0-logloss:0.00002
# [332]	validation_0-logloss:0.00002
# [333]	validation_0-logloss:0.00002
# [334]	validation_0-logloss:0.00002
# [335]	validation_0-logloss:0.00002
# [336]	validation_0-logloss:0.00002
# [337]	validation_0-logloss:0.00002
# [338]	validation_0-logloss:0.00002
# [339]	validation_0-logloss:0.00002
# [340]	validation_0-logloss:0.00002
# [341]	validation_0-logloss:0.00002
# [342]	validation_0-logloss:0.00002
# [343]	validation_0-logloss:0.00002
# [344]	validation_0-logloss:0.00002
# [345]	validation_0-logloss:0.00002
# [346]	validation_0-logloss:0.00002
# [347]	validation_0-logloss:0.00002
# [348]	validation_0-logloss:0.00002
# [349]	validation_0-logloss:0.00002
# [350]	validation_0-logloss:0.00002
# [351]	validation_0-logloss:0.00002
# [352]	validation_0-logloss:0.00002
# [353]	validation_0-logloss:0.00002
# [354]	validation_0-logloss:0.00002
# [355]	validation_0-logloss:0.00002
# [356]	validation_0-logloss:0.00002
# [357]	validation_0-logloss:0.00002
# [358]	validation_0-logloss:0.00002
# [359]	validation_0-logloss:0.00002
# [360]	validation_0-logloss:0.00002
# [361]	validation_0-logloss:0.00002
# [362]	validation_0-logloss:0.00002
# [363]	validation_0-logloss:0.00002
# [364]	validation_0-logloss:0.00002
# [365]	validation_0-logloss:0.00002
# [366]	validation_0-logloss:0.00002
# [367]	validation_0-logloss:0.00002
# [368]	validation_0-logloss:0.00002
# [369]	validation_0-logloss:0.00002
# [370]	validation_0-logloss:0.00002
# [371]	validation_0-logloss:0.00002
# [372]	validation_0-logloss:0.00002
# [373]	validation_0-logloss:0.00002
# [374]	validation_0-logloss:0.00002
# [375]	validation_0-logloss:0.00002
# [376]	validation_0-logloss:0.00002
# [377]	validation_0-logloss:0.00002
# [378]	validation_0-logloss:0.00002
# [379]	validation_0-logloss:0.00002
# [380]	validation_0-logloss:0.00002
# [381]	validation_0-logloss:0.00002
# [382]	validation_0-logloss:0.00002
# [383]	validation_0-logloss:0.00002
# [384]	validation_0-logloss:0.00002
# [385]	validation_0-logloss:0.00002
# [386]	validation_0-logloss:0.00002
# [387]	validation_0-logloss:0.00002
# [388]	validation_0-logloss:0.00002
# [389]	validation_0-logloss:0.00002
# [390]	validation_0-logloss:0.00002
# [391]	validation_0-logloss:0.00002
# [392]	validation_0-logloss:0.00002
# [393]	validation_0-logloss:0.00002
# [394]	validation_0-logloss:0.00002
# [395]	validation_0-logloss:0.00002
# [396]	validation_0-logloss:0.00002
# [397]	validation_0-logloss:0.00002
# [398]	validation_0-logloss:0.00002
# [399]	validation_0-logloss:0.00002
# [400]	validation_0-logloss:0.00002
# [401]	validation_0-logloss:0.00002
# [402]	validation_0-logloss:0.00002
# [403]	validation_0-logloss:0.00002
# [404]	validation_0-logloss:0.00002
# [405]	validation_0-logloss:0.00002
# [406]	validation_0-logloss:0.00002
# [407]	validation_0-logloss:0.00002
# [408]	validation_0-logloss:0.00002
# [409]	validation_0-logloss:0.00002
# [410]	validation_0-logloss:0.00002
# [411]	validation_0-logloss:0.00002
# [412]	validation_0-logloss:0.00002
# [413]	validation_0-logloss:0.00002
# [414]	validation_0-logloss:0.00002
# [415]	validation_0-logloss:0.00002
# [416]	validation_0-logloss:0.00002
# [417]	validation_0-logloss:0.00002
# [418]	validation_0-logloss:0.00002
# [419]	validation_0-logloss:0.00002
# [420]	validation_0-logloss:0.00002
# [421]	validation_0-logloss:0.00002
# [422]	validation_0-logloss:0.00002
# [423]	validation_0-logloss:0.00002
# [424]	validation_0-logloss:0.00002
# [425]	validation_0-logloss:0.00002
# [426]	validation_0-logloss:0.00002
# [427]	validation_0-logloss:0.00002
# [428]	validation_0-logloss:0.00002
# [429]	validation_0-logloss:0.00002
# [430]	validation_0-logloss:0.00002
# [431]	validation_0-logloss:0.00002
# [432]	validation_0-logloss:0.00002
# [433]	validation_0-logloss:0.00002
# [434]	validation_0-logloss:0.00002
# [435]	validation_0-logloss:0.00002
# [436]	validation_0-logloss:0.00002
# [437]	validation_0-logloss:0.00002
# [438]	validation_0-logloss:0.00002
# [439]	validation_0-logloss:0.00002
# [440]	validation_0-logloss:0.00002
# [441]	validation_0-logloss:0.00002
# [442]	validation_0-logloss:0.00002
# [443]	validation_0-logloss:0.00002
# [444]	validation_0-logloss:0.00002
# [445]	validation_0-logloss:0.00002
# [446]	validation_0-logloss:0.00002
# [447]	validation_0-logloss:0.00002
# [448]	validation_0-logloss:0.00002
# [449]	validation_0-logloss:0.00002
# [450]	validation_0-logloss:0.00002
# [451]	validation_0-logloss:0.00002
# [452]	validation_0-logloss:0.00002
# [453]	validation_0-logloss:0.00002
# [454]	validation_0-logloss:0.00002
# [455]	validation_0-logloss:0.00002
# [456]	validation_0-logloss:0.00002
# [457]	validation_0-logloss:0.00002
# [458]	validation_0-logloss:0.00002
# [459]	validation_0-logloss:0.00002
# [460]	validation_0-logloss:0.00002
# [461]	validation_0-logloss:0.00002
# [462]	validation_0-logloss:0.00002
# [463]	validation_0-logloss:0.00002
# [464]	validation_0-logloss:0.00002
# [465]	validation_0-logloss:0.00002
# [466]	validation_0-logloss:0.00002
# [467]	validation_0-logloss:0.00002
# [468]	validation_0-logloss:0.00002
# [469]	validation_0-logloss:0.00002
# [470]	validation_0-logloss:0.00002
# [471]	validation_0-logloss:0.00002
# [472]	validation_0-logloss:0.00002
# [473]	validation_0-logloss:0.00002
# [474]	validation_0-logloss:0.00002
# [475]	validation_0-logloss:0.00002
# [476]	validation_0-logloss:0.00002
# [477]	validation_0-logloss:0.00002
# [478]	validation_0-logloss:0.00002
# [479]	validation_0-logloss:0.00002
# [480]	validation_0-logloss:0.00002
# [481]	validation_0-logloss:0.00002
# [482]	validation_0-logloss:0.00002
# [483]	validation_0-logloss:0.00002
# [484]	validation_0-logloss:0.00002
# [485]	validation_0-logloss:0.00002
# [486]	validation_0-logloss:0.00002
# [487]	validation_0-logloss:0.00002
# [488]	validation_0-logloss:0.00002
# [489]	validation_0-logloss:0.00002
# [490]	validation_0-logloss:0.00002
# [491]	validation_0-logloss:0.00002
# [492]	validation_0-logloss:0.00002
# [493]	validation_0-logloss:0.00002
# [494]	validation_0-logloss:0.00002
# [495]	validation_0-logloss:0.00002
# [496]	validation_0-logloss:0.00002
# [497]	validation_0-logloss:0.00002
# [498]	validation_0-logloss:0.00002
# [499]	validation_0-logloss:0.00002
#
# 🚀 **Computational Overhead Report (XGBoost Training)** 🚀
# ⏳ **Execution Time:** 12.7825 seconds
# 🔥 **CPU Usage Change:** 13.10%
# 💾 **Disk I/O Usage:** 24.90 MB
# 📊 **Memory Usage:** -87.62 MB

# %% [markdown]
# # Validate the Model

# %%
# Predict on validation set
y_val_pred = xgb_model.predict(X_val)

# Compute validation metrics
val_accuracy = accuracy_score(y_val, y_val_pred)
val_precision = precision_score(y_val, y_val_pred, average='binary')
val_recall = recall_score(y_val, y_val_pred, average='binary')
val_f1 = f1_score(y_val, y_val_pred, average='binary')

# Display validation results
print("\n🚀 **Validation Results:**")
print(f"✅ Accuracy:   {val_accuracy:.2%}")
print(f"✅ Precision:  {val_precision:.2%}")
print(f"✅ Recall:     {val_recall:.2%}")
print(f"✅ F1-score:   {val_f1:.2%}")
# Out:
# 🚀 **Validation Results:**
# ✅ Accuracy:   100.00%
# ✅ Precision:  100.00%
# ✅ Recall:     100.00%
# ✅ F1-score:   100.00%

# %% [markdown]
# # Test the Model

# %%
# Start time and resource tracking
start_time = time.time()
cpu_before, memory_before, disk_io_before = measure_system_resources()

# Predict on test set
y_test_pred = xgb_model.predict(X_test)

# Compute test metrics
test_accuracy = accuracy_score(y_test, y_test_pred)
test_precision = precision_score(y_test, y_test_pred, average='binary')
test_recall = recall_score(y_test, y_test_pred, average='binary')
test_f1 = f1_score(y_test, y_test_pred, average='binary')

# End time and resource tracking
end_time = time.time()
cpu_after, memory_after, disk_io_after = measure_system_resources()
execution_time = end_time - start_time

cpu_usage_change = cpu_after - cpu_before
memory_used = memory_after - memory_before
disk_io_used = disk_io_after - disk_io_before

# Display test results
print("\n🚀 **Test Results:**")
print(f"✅ Accuracy:   {test_accuracy:.2%}")
print(f"✅ Precision:  {test_precision:.2%}")
print(f"✅ Recall:     {test_recall:.2%}")
print(f"✅ F1-score:   {test_f1:.2%}")

# Report computational overhead
print("\n🚀 **Computational Overhead Report (XGBoost Testing)** 🚀")
print(f"⏳ **Execution Time:** {execution_time:.4f} seconds")
print(f"🔥 **CPU Usage Change:** {cpu_usage_change:.2f}%")
print(f"💾 **Disk I/O Usage:** {disk_io_used:.2f} MB")
print(f"📊 **Memory Usage:** {memory_used:.2f} MB")
# Out:
# 🚀 **Test Results:**
# ✅ Accuracy:   99.99%
# ✅ Precision:  100.00%
# ✅ Recall:     99.99%
# ✅ F1-score:   99.99%
#
# 🚀 **Computational Overhead Report (XGBoost Testing)** 🚀
# ⏳ **Execution Time:** 1.0951 seconds
# 🔥 **CPU Usage Change:** 18.30%
# 💾 **Disk I/O Usage:** 2.99 MB
# 📊 **Memory Usage:** 3.05 MB

# %%
accuracy = accuracy_score(y_test, pred)
precision = precision_score(y_test, pred)
recall = recall_score(y_test, pred)
f1 = f1_score(y_test, pred)

print("Accuracy:   {:.2%}".format(accuracy))
print("Precision:  {:.2%}".format(precision))
print("Recall:     {:.2%}".format(recall))
print("F1-score:   {:.2%}".format(f1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 accuracy = accuracy_score(y_train_test, pred)
#       2 precision = precision_score(y_train_test, pred)
#       3 recall = recall_score(y_train_test, pred)
#
# NameError: name 'y_train_test' is not defined

# %% [markdown]
# # Visualizing Feature Importance

# %%
# Plot the feature importance
plt.figure(figsize=(10, 6))
plot_importance(xgb_model, max_num_features=10, importance_type='gain', title="XGBoost Feature Importance")
plt.show()

# %% [markdown]
# # Confusion Matrix & Classification Report

# %%
# Generate confusion matrix
cm = confusion_matrix(y_test, y_test_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal', 'Malicious'])
disp.plot(cmap='YlGnBu', values_format='d')

plt.title("Confusion Matrix - XGBoost")
plt.show()

# Print classification report
print("\n🚀 **Classification Report:**")
print(classification_report(y_test, y_test_pred))
# Out:
# 🚀 **Classification Report:**
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     12729
#            1       1.00      1.00      1.00     15880
#
#     accuracy                           1.00     28609
#    macro avg       1.00      1.00      1.00     28609
# weighted avg       1.00      1.00      1.00     28609

# %% [markdown]
# # Save the Trained XGBoost Model

# %%
# Save the trained model
model_folder = "../../3_Post-Modeling-Phase/Trained_ML_models/Models_CICIDS-2017/"
model_filename = "CICIDS-2017_XGBoost.joblib"
model_path = model_folder + model_filename
joblib.dump(xgb_model, model_path)

print(f"🚀 **XGBoost model saved to:** {model_path}")
# Out:
# 🚀 **XGBoost model saved to:** ../../3_Post-Modeling-Phase/Trained_ML_models/Models_CICIDS-2017/CICIDS-2017_XGBoost.joblib
